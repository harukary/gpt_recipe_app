# %%
from pydantic import BaseModel, create_model
import json

recipe_format = json.loads(open('../server/app/config/recipe_format.json', 'r').read())
Recipe = create_model('Recipe', **recipe_format)
print(Recipe.schema_json(indent=2,ensure_ascii=False))
# Out:
# {
#   "title": "Recipe",
#   "type": "object",
#   "properties": {
#     "name": {
#       "title": "Name",
#       "default": "レシピ名",
#       "type": "string"
#     },
#     "description": {
#       "title": "Description",
#       "default": "レシピの説明",
#       "type": "string"
#     },
#     "image": {
#       "title": "Image",
#       "default": "レシピ画像URL",
#       "type": "string"
#     },
#     "cooking_time": {
#       "title": "Cooking Time",
#       "default": "調理時間",
#       "type": "string"
#     },
#     "dish_types": {
#       "title": "Dish Types",
#       "default": [
#         "主菜・副菜などの種類"
#       ],
#       "type": "array",
#       "items": {}
#     },
#     "cuisine_types": {
#       "title": "Cuisine Types",
#       "default": [
#         "料理の国籍・地域"
#       ],
#       "type": "array",
#       "items": {}
#     },
#     "nutrition": {
#       "title": "Nutrition",
#       "default": {
#         "calorie": 0,
#         "protein": 0.0,
#         "lipid": 0.0,
# ...
